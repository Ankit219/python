# %% [markdown]
# # question (1) you all are pilots, you want to land a plane safely, so WAP to take current altitude as input and check weather the altitude is less than 1000 ft to land the plane, or more than 1000ft, and if it's less than 5000ft ask pilot to bring it further down to 1000ft and if it is more than 5000ft then ask pilot to turn around and attempt later.

# %%
altitude = 1000
altitude1 =5000
if altitude <= 1000:
    print("go to safe landing")
    print("go to safe landing")
elif altitude1 >5000:
    print("turn around and attempt later")
    print("turn around and attempt later")
else:
    print("bring it further down to thousand ft")
    print("bring it further down to thousand ft")
# Out:
# go to safe landing
# go to safe landing

# %% [markdown]
# # question 2. using a loop please print all the prime numbers between 1-200 using FOR LOOP AND RANGE function.

# %%
for item in range(1,200):
    if item%2==0:
        print(item, "is prime number")

    else:
        print(item, "is non prime number")
# Out:
# 1 is non prime number
# 2 is prime number
# 3 is non prime number
# 4 is prime number
# 5 is non prime number
# 6 is prime number
# 7 is non prime number
# 8 is prime number
# 9 is non prime number
# 10 is prime number
# 11 is non prime number
# 12 is prime number
# 13 is non prime number
# 14 is prime number
# 15 is non prime number
# 16 is prime number
# 17 is non prime number
# 18 is prime number
# 19 is non prime number
# 20 is prime number
# 21 is non prime number
# 22 is prime number
# 23 is non prime number
# 24 is prime number
# 25 is non prime number
# 26 is prime number
# 27 is non prime number
# 28 is prime number
# 29 is non prime number
# 30 is prime number
# 31 is non prime number
# 32 is prime number
# 33 is non prime number
# 34 is prime number
# 35 is non prime number
# 36 is prime number
# 37 is non prime number
# 38 is prime number
# 39 is non prime number
# 40 is prime number
# 41 is non prime number
# 42 is prime number
# 43 is non prime number
# ...
